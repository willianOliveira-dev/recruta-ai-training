# %% [markdown]
# # Recruta AI Treinamento - Google Colab
#
# Este notebook prepara o ambiente e orquestra o treinamento do modelo **Recruta 1.0 Micro** (`unsloth/Llama-3.2-3B-Instruct`).
# Ele fara o download dos datasets do Hugging Face e executara o Fine-Tuning otimizado via Unsloth.
#
# > **IMPORTANTE**: Voce precisara registrar os seguintes segredos (`Secrets`) na barra lateral do Colab:
# >
# > Acesse: https://huggingface.co/settings/tokens
# >
# > 1. `HF_TOKEN` (seu token do Hugging Face para envio e download de modelos)
# > 2. `WANDB_API_KEY` (opcional, para telemetria de treinamento via Weights & Biases)
#
# ---

# %%
# !pip install uv

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
os.environ["WANDB_API_KEY"] = userdata.get("WANDB_API_KEY")

print("Tokens configurados com sucesso.")

# %% [markdown]
# ## 1. Clonando o Repositório e Sincronizando Pacotes
#
# Aponte para o repositório público do Recruta AI Training.

# %%
# !git clone https://github.com/willianOliveira-dev/recruta-ai-training.git
# %cd recruta-ai-training
# !uv sync
# Out:
# Cloning into 'recruta-ai-training'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 133 (delta 34), reused 124 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (133/133), 118.78 KiB | 2.42 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/recruta-ai-training
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# ^C

# %% [markdown]
# ## 2. Ingestao de Dados e Treinamento
#
# Baixamos os dados do Hugging Face, formatamos e treinamos seguindo o Pipeline tipado e validado.
# O script abaixo orquestra toda a pipeline: ingestao, preparacao do dataset, carregamento do modelo com Unsloth, fine-tuning via LoRA e publicacao no Hugging Face Hub.

# %%
# !uv run scripts/train.py --config configs/micro.yaml
